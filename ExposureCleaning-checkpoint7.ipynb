# %% [markdown]
# # Gathering data

# %% [markdown]
# ## Header

# %%
#header of imports
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.optimize import curve_fit

from astropy.io import fits
from astropy.wcs import WCS

from photutils.detection import DAOStarFinder
from astropy.stats import mad_std

from astropy.stats import sigma_clipped_stats
from astropy.stats import SigmaClip

from astropy import units as u
from photutils.background import Background2D, MedianBackground
from photutils.aperture import aperture_photometry, CircularAnnulus, CircularAperture

import csv

import astrometry
import pandas as pd
import astropy.units as u

import astropy as ap

solver = astrometry.Solver(
    astrometry.series_5200.index_files(
        cache_directory="astrometry_cache",
        scales={1,3},
    )
)

import logging
# !pip install astroalign
from reproject import reproject_interp
from collections import defaultdict
from scipy.ndimage import shift as ndi_shift
from astropy.coordinates import SkyCoord, match_coordinates_sky

from astropy.visualization import PercentileInterval, AsinhStretch, ImageNormalize
import astroalign as aa
# %matplotlib inline
# Out:
# INFO:root:loaded 96 index files
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: astroalign in ./.local/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: numpy>=1.17 in ./.local/lib/python3.10/site-packages (from astroalign) (1.26.4)
# Requirement already satisfied: scipy>=0.15 in /data0/sw/anaconda3/lib/python3.10/site-packages (from astroalign) (1.11.4)
# Requirement already satisfied: scikit-image in /data0/sw/anaconda3/lib/python3.10/site-packages (from astroalign) (0.22.0)
# Requirement already satisfied: sep-pjw in ./.local/lib/python3.10/site-packages (from astroalign) (1.3.8)
# Requirement already satisfied: networkx>=2.8 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (10.3.0)
# Requirement already satisfied: imageio>=2.27 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (2024.2.12)
# Requirement already satisfied: packaging>=21 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (24.0)
# Requirement already satisfied: lazy_loader>=0.3 in /data0/sw/anaconda3/lib/python3.10/site-packages (from scikit-image->astroalign) (0.3)
# Requirement already satisfied: sep>=1.4.0 in ./.local/lib/python3.10/site-packages (from sep-pjw->astroalign) (1.4.1)

# %% [markdown]
# ## Functions

# %%
#defining a function that corrects the bias:
def BiasCorrection(filenum):
    #Defining bias_image
    filename = 'bias.fits'
    hdu = fits.open(filename)[0]
    bias_image = hdu.data
    hdr = hdu.header

    #create a dictionary for the corrected files
    corrected = {}
    
    for i in range(1, filenum+1):
        filename = f'23feb.{i:04d}.fits'
        hdu = fits.open(filename)[0]
        image = hdu.data
        hdr = hdu.header
        
        #subtract and store in dictionary
        bias = image - bias_image
        filt = hdr.get('FILTER')
        exposure = hdr.get('EXPTIME')
        corrected[filename] = {
        'data': bias,
        'filter': filt,
        'exposure': exposure,
        'img': hdu
        }

    #returns the dictionary
    return corrected

# %%
#Defining function that flatfields:
def Flatfielding(corrected):
    #create a dictionary of the filters
    flatdict = {
        'Harris-R': 'rflat.fits',
        'Harris-V': 'vflat.fits',
        'Harris-B': 'bflat.fits',
        'Bessell-U': 'uflat.fits',
    }
    #interate across dict
    for file, info in corrected.items():
        data = info['data']
        filt = info['filter']
        #grab flat field fits
        flat = flatdict.get(filt)

        hdu = fits.open(flat)[0]
        flatdata = hdu.data
        
        info['flatdata'] = data / flatdata
    return corrected

# %%
#Defining function that finds background
def Background(corrected):
    for file, info in corrected.items():
        image = info['flatdata']
        mean, median, std = sigma_clipped_stats(image, sigma=3.0)
        sigma_clip = SigmaClip(sigma=3.0)
        bkg_estimator = MedianBackground()

        bkg = Background2D(image, (50, 50), filter_size=(3,3),sigma_clip=sigma_clip,bkg_estimator=bkg_estimator)

        image = image - bkg.background
        info['bgsub'] = image
    return corrected

# %%
#Defining function that finds stars:
def Starfinding(corrected):
    #blank dictionary for star data
    tables = {}

    #goes through dictionary and uses code from workbook6
    for file, info in corrected.items():
        image = info['flatdata']
        
        bkg_sigma = mad_std(image)

        daofind = DAOStarFinder(fwhm=4.0, threshold=100.0 * bkg_sigma)

        sources = daofind(image)

        for col in sources.colnames:
            sources[col].info.format = '%.8g' 
            
        sources = sources[sources['ycentroid'] >= 1]
        positions = np.transpose((sources['xcentroid'], sources['ycentroid']))

        radii = [3.0, 4.0, 5.0,7.0,10.0,15.0,25.0,40.0]

        apertures = [CircularAperture(positions, r=r) for r in radii]
        
        phot_table = aperture_photometry(image, apertures)
        #adds tables to the dictionary
        tables[file] = phot_table

    return tables, radii

# %%
#Define astropy function
def astropy(groups):
    logging.getLogger().setLevel(logging.INFO)
    unit = 'pix'
    for filt, trials in groups.items():
        for file, info in trials.items():
            x = info['position'][0]
            y = info['position'][1]
            stars = [(x[i], y[i]) for i in range(0,len(x))]
            solution = solver.solve(
                stars=stars,
                size_hint=None,
                position_hint=astrometry.PositionHint(
                    ra_deg=114.73,
                    dec_deg=38,
                    radius_deg=1.0),
        solution_parameters=astrometry.SolutionParameters(),
)    
            if solution.has_match():
                info['wcs'] = solution.best_match().astropy_wcs()
    return groups

# %%
#define stacking function
def stacking(filt):
    ref_file, first_info = next(iter(filt.items()))
    ref_wcs   = first_info['wcs']
    ref_shape = first_info['data'].shape
    reprojected = []
    for files, file in filt.items():
        data = file['flatdata']
        wcs = file['wcs']
        dataproj, _ = reproject_interp((data, wcs), ref_wcs,shape_out=ref_shape)
        reprojected.append(dataproj)
    stack = np.median(np.stack(reprojected, axis=0), axis=0)
    hdu = fits.PrimaryHDU(stack, header=ref_wcs.to_header())
    out = f'stack_{files.replace(" ", "_")}.fits'
    hdu.writeto(out, overwrite=True)
    print(f"Wrote {out}, shape = {stack.shape}")
    bkg = Background2D(image, box_size=(50, 50), filter_size=(3, 3), bkg_estimator=MedianBackground())
    data = stack - bkg.background
    mean, median, std = sigma_clipped_stats(data, sigma=3.0)
    print("min, max, mean:", np.nanmin(stack), np.nanmax(stack), np.nanmean(stack))
        # 3) Run DAOStarFinder at 5σ above background
    daofind = DAOStarFinder(fwhm=4.0, threshold=50.0 * std)
    sources = daofind(data)
    for col in sources.colnames:
        sources[col].info.format = '%.8g' 
            
    sources = sources[sources['ycentroid'] >= 1]
    positions = np.transpose((sources['xcentroid'], sources['ycentroid']))

    radii = [3.0, 4.0, 5.0,7.0,10.0,15.0,25.0,40.0]

    apertures = [CircularAperture(positions, r=r) for r in radii]
        
    phot_table = aperture_photometry(stack, apertures)  

    solution = solver.solve(
            stars=stars,
            size_hint=None,
            position_hint=astrometry.PositionHint(
                ra_deg=114.73,
                dec_deg=38,
                radius_deg=1.0),
            solution_parameters=astrometry.SolutionParameters(),
        )    
        
        # defines new wcs reference frame using solved for values
        
    if solution.has_match():
            wcs = solution.best_match().astropy_wcs()
    if solution.has_match():
        for star in solution.best_match().stars:
            print(f"{star.ra_deg}, {star.dec_deg}:") 
            print(star)  # Often this dumps the available fields
    if solution.has_match():
        wcs = solution.best_match().astropy_wcs()
        pixels = wcs.all_world2pix(
            [[star.ra_deg, star.dec_deg] for star in solution.best_match().stars],
            0,
        )
    
    norm = ImageNormalize(
        stack,
        interval=PercentileInterval(99.5),
        stretch=AsinhStretch()
    )
    
    fig = plt.figure(figsize=(20,20))
    ax  = fig.add_subplot(projection=wcs)
    
    # draw the stretched image
    im = ax.imshow(
        stack,
        origin='lower',
        norm=norm,
        cmap='viridis'
    )
    ax.grid(color='white', ls='solid', alpha=1)
    ax.set_xlabel('Right Ascension', fontsize=24)
    ax.set_ylabel('Declination',    fontsize=24)
    fig.colorbar(im, ax=ax, label='counts')
    plt.show()
    header = hdu.header
    wcs    = WCS(header)
    return stack, header, wcs, phot_table

# %%
#new stacking
def Stack(filt):
    ref_file, first_info = next(iter(filt.items()))
    ref_wcs   = first_info['wcs']
    ref_shape = first_info['flatdata'].shape
    img_aligned = first_info['flatdata']
    for  files, file in filt.items():
        img = file['flatdata']
        img_aligned, _ = aa.register(img_aligned, img, detection_sigma=3.0)
    return img_aligned

# %%
def hlr(image, x0, y0):
    y, x = np.indices(image.shape)
    r = np.hypot(x - x0, y - y0)
    dr = 1.0
    
    r_max = np.min([x0, y0, image.shape[0]-y0, image.shape[1]-x0])

    radii = np.arange(0, r_max, dr)
    cumflux = np.array([np.nansum(image[r <= rad]) for rad in radii])

    total_flux = cumflux[-1]
    half_flux = total_flux / 2.0

    idx = np.searchsorted(cumflux, half_flux)
    R_half = radii[idx]

    plt.figure(figsize=(6,4))
    plt.plot(radii, cumflux, 'o-', label='Curve of Growth')
    plt.axvline(R_half, color='red', linestyle='--', label=f'R₁/₂ = {R_half:.1f} px')
    plt.xlabel("Radius (pixels)")
    plt.ylabel("Cumulative Flux")
    plt.legend()
    plt.tight_layout()
    plt.show()

    return R_half

# %%
def mass(r_half):
    plate_scale = 0.15  # arcsec/pix
    distance   = 88500  # pc (distance to NGC2419)
    r_pix = r_half        # half-light radius in px from your code
    
    # convert to arcsec
    r_arcsec = r_pix * plate_scale
    # convert to radians
    r_rad = (r_arcsec * u.arcsec).to(u.rad).value
    # physical radius (pc)
    r_pc = distance * r_rad
    
    # constants
    G = 4.302e-3    # pc·(km/s)^2 / M_sun
    
    # your measured values
    hlr_pc = r_pc     # from earlier: physical half-light radius in pc
    sigma = 3.7       # km/s, e.g. from your spectra
    
    # Wolf et al. mass estimator
    M_half = 4 * sigma**2 * hlr_pc / G
    
    print(f"M_1/2 = {M_half:.2e} M_sun")
    print(f"M_1/2*2 = {M_half*2.0:.2e} M_sun")

# %% [markdown]
# ## Running Code

# %%
#running some code
corrected = BiasCorrection(56)
corrected = Flatfielding(corrected)
tables = Starfinding(corrected)

# %%
#group starfinding info with files and files with filters
groups = {
        'Harris-R': {},
        'Harris-V': {},
        'Harris-B': {},
        'Bessell-U': {}
    }
for file, info in corrected.items():
        filt = info['filter']
        tbl = tables[file]
        x = tbl['xcenter'].value    
        y = tbl['ycenter'].value  
        if filt == 'Harris-R':
            groups[filt][file] = info
        elif filt == 'Harris-V':
            groups[filt][file] = info
        elif filt == 'Harris-B':
            groups[filt][file] = info
        elif filt == 'Bessell-U':
            groups[filt][file] = info
        groups[filt][file]['position']=[x,y]

# %%
#LONG CODE RUNS ASTROPY FOR EACH FILE AND STORES WCS
groups = astropy(groups)
# Out:
# INFO:root:solve 57: start
# INFO:root:solve 57: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 57: logodds=142.777, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425611, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=143.271, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.424874, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=134.66, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428704, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=144.971, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.42792, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=151.965, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425242, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=148.687, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427714, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=148.517, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427246, index="5200/index-5201-05.fits"
# INFO:root:solve 57: logodds=151.692, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427396, index="5200/index-5201-05.fits"
# INFO:root:solve 57: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 58: start
# INFO:root:solve 58: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 58: logodds=136.726, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425743, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=137.364, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425041, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=128.51, matches=23, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428321, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=138.9, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427731, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=145.446, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425419, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=142.008, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427535, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=142.023, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427168, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=144.949, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427267, index="5200/index-5201-05.fits"
# INFO:root:solve 58: logodds=128.889, matches=23, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.427647, index="5200/index-5201-05.fits"
# INFO:root:solve 58: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 58: logodds=167.54, matches=20, conflicts=0, distractors=7, ra=114.538, dec=38.8881, scale=0.425735, index="5200/index-5203-05.fits"
# INFO:root:solve 59: start
# INFO:root:solve 59: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 59: logodds=147.939, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425703, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=148.594, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.424937, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=140.002, matches=25, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428794, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=150.387, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427981, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=158.039, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425245, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=154.909, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427745, index="5200/index-5201-05.fits"
# INFO:root:solve 59: logodds=154.721, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427261, index="5200/index-5201-05.fits"
# INFO:root:solve 59: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 59: logodds=180.927, matches=22, conflicts=0, distractors=6, ra=114.538, dec=38.8879, scale=0.427727, index="5200/index-5203-05.fits"
# INFO:root:solve 59: logodds=180.642, matches=22, conflicts=0, distractors=6, ra=114.538, dec=38.8879, scale=0.426551, index="5200/index-5203-05.fits"
# INFO:root:solve 59: logodds=181.12, matches=22, conflicts=0, distractors=6, ra=114.538, dec=38.8879, scale=0.42707, index="5200/index-5203-05.fits"
# INFO:root:solve 60: start
# INFO:root:solve 60: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 60: logodds=137.365, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.42583, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=138.072, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425062, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=129.106, matches=23, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428394, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=139.464, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427801, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=146.048, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.42542, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=142.582, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427578, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=142.586, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427212, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=145.558, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427306, index="5200/index-5201-05.fits"
# INFO:root:solve 60: logodds=129.513, matches=23, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.427667, index="5200/index-5201-05.fits"
# INFO:root:solve 60: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 60: logodds=167.66, matches=20, conflicts=0, distractors=7, ra=114.538, dec=38.8881, scale=0.425786, index="5200/index-5203-05.fits"
# INFO:root:solve 61: start
# INFO:root:solve 61: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 61: logodds=146.795, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8879, scale=0.425665, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=147.527, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8879, scale=0.424905, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=138.754, matches=25, conflicts=0, distractors=6, ra=114.538, dec=38.8881, scale=0.428825, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=149.246, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8883, scale=0.428013, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=157.766, matches=26, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425257, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=153.741, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.427786, index="5200/index-5201-05.fits"
# INFO:root:solve 61: logodds=153.619, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.427299, index="5200/index-5201-05.fits"
# INFO:root:solve 61: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 61: logodds=180.476, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8885, scale=0.427678, index="5200/index-5203-05.fits"
# INFO:root:solve 61: logodds=180.23, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8883, scale=0.426541, index="5200/index-5203-05.fits"
# INFO:root:solve 61: logodds=180.674, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8883, scale=0.42706, index="5200/index-5203-05.fits"
# INFO:root:solve 62: start
# INFO:root:solve 62: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 62: logodds=146.925, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8879, scale=0.425688, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=147.618, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8879, scale=0.424942, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=138.863, matches=25, conflicts=0, distractors=6, ra=114.538, dec=38.8881, scale=0.428739, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=149.359, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8883, scale=0.427948, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=157.876, matches=26, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425279, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=153.864, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.427726, index="5200/index-5201-05.fits"
# INFO:root:solve 62: logodds=153.723, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.427257, index="5200/index-5201-05.fits"
# INFO:root:solve 62: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 62: logodds=180.581, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8885, scale=0.427647, index="5200/index-5203-05.fits"
# INFO:root:solve 62: logodds=180.343, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8883, scale=0.426516, index="5200/index-5203-05.fits"
# INFO:root:solve 62: logodds=180.782, matches=22, conflicts=0, distractors=8, ra=114.538, dec=38.8883, scale=0.427024, index="5200/index-5203-05.fits"
# INFO:root:solve 63: start
# INFO:root:solve 63: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 63: logodds=155.193, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425858, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=154.133, matches=27, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425856, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=154.241, matches=27, conflicts=0, distractors=4, ra=114.538, dec=38.8885, scale=0.427692, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=155.174, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425077, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=146.731, matches=26, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428236, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=158.264, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427708, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=157.366, matches=27, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.427706, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=165.318, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425331, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=162.477, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427525, index="5200/index-5201-05.fits"
# INFO:root:solve 63: logodds=162.353, matches=27, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427164, index="5200/index-5201-05.fits"
# INFO:root:solve 63: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 64: start
# INFO:root:solve 64: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 64: logodds=148.433, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425771, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=147.518, matches=26, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425772, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=148.612, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8885, scale=0.427666, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=149.33, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425023, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=140.879, matches=25, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428339, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=151.283, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427725, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=150.296, matches=26, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.427727, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=158.787, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425302, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=155.77, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427539, index="5200/index-5201-05.fits"
# INFO:root:solve 64: logodds=155.656, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427148, index="5200/index-5201-05.fits"
# INFO:root:solve 64: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 65: start
# INFO:root:solve 65: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 65: logodds=138.057, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.426139, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=137.031, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.426138, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=138.168, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425366, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=129.012, matches=23, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427429, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=140.701, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427349, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=139.766, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.427348, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=146.42, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425695, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=143.035, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427201, index="5200/index-5201-05.fits"
# INFO:root:solve 65: logodds=143.283, matches=24, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427077, index="5200/index-5201-05.fits"
# INFO:root:solve 65: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 66: start
# INFO:root:solve 66: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 66: logodds=149.215, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425652, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=149.879, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.424932, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=141.332, matches=25, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.428583, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=151.84, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427852, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=159.278, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425274, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=156.324, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427662, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=156.158, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427217, index="5200/index-5201-05.fits"
# INFO:root:solve 66: logodds=159.498, matches=26, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427363, index="5200/index-5201-05.fits"
# INFO:root:solve 66: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 67: start
# INFO:root:solve 67: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 67: logodds=125.455, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425737, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=116.025, matches=21, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.42837, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=126.583, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427747, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=133.014, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425366, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=129.752, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427552, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=129.772, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427167, index="5200/index-5201-05.fits"
# INFO:root:solve 67: logodds=123.094, matches=22, conflicts=0, distractors=3, ra=114.538, dec=38.8878, scale=0.427014, index="5200/index-5201-05.fits"
# INFO:root:solve 67: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 67: logodds=158.933, matches=19, conflicts=0, distractors=6, ra=114.538, dec=38.8881, scale=0.425691, index="5200/index-5203-05.fits"
# INFO:root:solve 67: logodds=154.561, matches=19, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.424276, index="5200/index-5203-05.fits"
# INFO:root:solve 67: logodds=155.101, matches=19, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.424213, index="5200/index-5203-05.fits"
# INFO:root:solve 67: logodds=159.097, matches=19, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.424664, index="5200/index-5203-05.fits"
# INFO:root:solve 67: logodds=156.796, matches=19, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.425859, index="5200/index-5203-05.fits"
# INFO:root:solve 68: start
# INFO:root:solve 68: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 68: logodds=137.427, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425813, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=136.466, matches=24, conflicts=0, distractors=5, ra=114.538, dec=38.8879, scale=0.425814, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=137.441, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8885, scale=0.427637, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=138.246, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425076, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=129.197, matches=23, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.428151, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=139.57, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.427632, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=138.588, matches=24, conflicts=0, distractors=5, ra=114.538, dec=38.8883, scale=0.427632, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=146.376, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425416, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=142.745, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427431, index="5200/index-5201-05.fits"
# INFO:root:solve 68: logodds=142.777, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427104, index="5200/index-5201-05.fits"
# INFO:root:solve 68: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 68: logodds=173.015, matches=21, conflicts=0, distractors=7, ra=114.538, dec=38.8888, scale=0.427546, index="5200/index-5203-05.fits"
# INFO:root:solve 68: logodds=172.109, matches=21, conflicts=0, distractors=8, ra=114.538, dec=38.8888, scale=0.427548, index="5200/index-5203-05.fits"
# INFO:root:solve 69: start
# INFO:root:solve 69: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 69: logodds=137.427, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.42574, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=137.979, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425027, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=128.938, matches=23, conflicts=0, distractors=5, ra=114.538, dec=38.8881, scale=0.428273, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=139.392, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.427697, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=146.018, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425396, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=142.509, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427504, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=142.494, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427145, index="5200/index-5201-05.fits"
# INFO:root:solve 69: logodds=145.456, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.427246, index="5200/index-5201-05.fits"
# INFO:root:solve 69: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 70: start
# INFO:root:solve 70: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 70: logodds=161.079, matches=29, conflicts=0, distractors=4, ra=114.544, dec=38.8916, scale=0.425579, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=160.106, matches=29, conflicts=0, distractors=5, ra=114.544, dec=38.8915, scale=0.42558, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=161.081, matches=29, conflicts=0, distractors=4, ra=114.544, dec=38.8922, scale=0.427881, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=162.288, matches=29, conflicts=0, distractors=4, ra=114.544, dec=38.8916, scale=0.424831, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=153.312, matches=28, conflicts=0, distractors=5, ra=114.544, dec=38.8917, scale=0.428637, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=163.918, matches=29, conflicts=0, distractors=4, ra=114.544, dec=38.892, scale=0.427904, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=162.918, matches=29, conflicts=0, distractors=5, ra=114.544, dec=38.8921, scale=0.427904, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=173.952, matches=29, conflicts=0, distractors=3, ra=114.544, dec=38.8916, scale=0.425256, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=169.545, matches=29, conflicts=0, distractors=4, ra=114.544, dec=38.8917, scale=0.427597, index="5200/index-5201-05.fits"
# INFO:root:solve 70: logodds=170.185, matches=29, conflicts=0, distractors=3, ra=114.544, dec=38.8918, scale=0.427128, index="5200/index-5201-05.fits"
# INFO:root:solve 70: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 71: start
# INFO:root:solve 71: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 71: logodds=99.6083, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.425328, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=99.1635, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8884, scale=0.427646, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=90.1899, matches=17, conflicts=0, distractors=5, ra=114.538, dec=38.888, scale=0.429336, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=99.359, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.428164, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=105.775, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425117, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=102.191, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.427981, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=101.587, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.427315, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=103.545, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426886, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=94.2688, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8877, scale=0.426179, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=103.799, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425623, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=102.575, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8877, scale=0.426336, index="5200/index-5201-05.fits"
# INFO:root:solve 71: logodds=102.248, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8877, scale=0.425952, index="5200/index-5201-05.fits"
# INFO:root:solve 71: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 71: logodds=150.529, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.426026, index="5200/index-5203-05.fits"
# INFO:root:solve 71: logodds=146.365, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424756, index="5200/index-5203-05.fits"
# INFO:root:solve 71: logodds=146.869, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424657, index="5200/index-5203-05.fits"
# INFO:root:solve 71: logodds=150.666, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425144, index="5200/index-5203-05.fits"
# INFO:root:solve 71: logodds=148.229, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426231, index="5200/index-5203-05.fits"
# INFO:root:solve 71: logodds=148.311, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8879, scale=0.426614, index="5200/index-5203-05.fits"
# INFO:root:solve 72: start
# INFO:root:solve 72: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 72: logodds=143.501, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425817, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=143.627, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8884, scale=0.427285, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=144.097, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425244, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=135.183, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.428047, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=145.759, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.427639, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=152.776, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425624, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=149.42, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427618, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=149.275, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427315, index="5200/index-5201-05.fits"
# INFO:root:solve 72: logodds=152.409, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427463, index="5200/index-5201-05.fits"
# INFO:root:solve 72: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 73: start
# INFO:root:solve 73: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 73: logodds=108.435, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425319, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=107.787, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8885, scale=0.427722, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=98.0927, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.429308, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=107.304, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.428135, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=113.914, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.425055, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=109.92, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427914, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=109.243, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427253, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=110.956, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.426823, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=100.906, matches=19, conflicts=0, distractors=3, ra=114.538, dec=38.8877, scale=0.426269, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=110.556, matches=20, conflicts=0, distractors=2, ra=114.538, dec=38.888, scale=0.425787, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=109.2, matches=20, conflicts=0, distractors=2, ra=114.538, dec=38.8877, scale=0.426427, index="5200/index-5201-05.fits"
# INFO:root:solve 73: logodds=108.909, matches=20, conflicts=0, distractors=2, ra=114.538, dec=38.8877, scale=0.426136, index="5200/index-5201-05.fits"
# INFO:root:solve 73: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 73: logodds=150.958, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.42601, index="5200/index-5203-05.fits"
# INFO:root:solve 73: logodds=146.782, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.42471, index="5200/index-5203-05.fits"
# INFO:root:solve 73: logodds=147.336, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424611, index="5200/index-5203-05.fits"
# INFO:root:solve 73: logodds=151.146, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425127, index="5200/index-5203-05.fits"
# INFO:root:solve 73: logodds=148.829, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426211, index="5200/index-5203-05.fits"
# INFO:root:solve 73: logodds=148.911, matches=18, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426585, index="5200/index-5203-05.fits"
# INFO:root:solve 74: start
# INFO:root:solve 74: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 74: logodds=129.09, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.8879, scale=0.425393, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=128.567, matches=23, conflicts=0, distractors=5, ra=114.531, dec=38.8884, scale=0.427589, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=130.056, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.8879, scale=0.424823, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=118.898, matches=22, conflicts=0, distractors=6, ra=114.531, dec=38.888, scale=0.429182, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=128.934, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.8883, scale=0.428087, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=137.842, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.888, scale=0.425123, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=133.988, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.8881, scale=0.427958, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=133.374, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.8881, scale=0.427325, index="5200/index-5201-05.fits"
# INFO:root:solve 74: logodds=135.57, matches=23, conflicts=0, distractors=5, ra=114.532, dec=38.888, scale=0.426966, index="5200/index-5201-05.fits"
# INFO:root:solve 74: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 74: logodds=166.245, matches=20, conflicts=0, distractors=7, ra=114.532, dec=38.8878, scale=0.42735, index="5200/index-5203-05.fits"
# INFO:root:solve 74: logodds=174.268, matches=21, conflicts=0, distractors=6, ra=114.532, dec=38.8878, scale=0.426606, index="5200/index-5203-05.fits"
# INFO:root:solve 74: logodds=174.968, matches=21, conflicts=0, distractors=6, ra=114.532, dec=38.8878, scale=0.427014, index="5200/index-5203-05.fits"
# INFO:root:solve 74: logodds=167.71, matches=20, conflicts=0, distractors=7, ra=114.531, dec=38.8881, scale=0.426044, index="5200/index-5203-05.fits"
# INFO:root:solve 74: logodds=173.99, matches=21, conflicts=0, distractors=6, ra=114.532, dec=38.8879, scale=0.427268, index="5200/index-5203-05.fits"
# INFO:root:solve 75: start
# INFO:root:solve 75: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 75: logodds=143.963, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.425849, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=144.563, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8879, scale=0.42525, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=135.64, matches=24, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.428098, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=146.182, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8883, scale=0.4277, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=153.217, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.42565, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=149.852, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427677, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=149.7, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.8881, scale=0.427378, index="5200/index-5201-05.fits"
# INFO:root:solve 75: logodds=152.835, matches=25, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.427524, index="5200/index-5201-05.fits"
# INFO:root:solve 75: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 76: start
# INFO:root:solve 76: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 76: logodds=146.555, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8911, scale=0.425936, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=146.748, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8916, scale=0.427428, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=147.32, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8911, scale=0.425323, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=138.645, matches=25, conflicts=0, distractors=6, ra=114.538, dec=38.8912, scale=0.42783, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=149.352, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8915, scale=0.42753, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=156.676, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8911, scale=0.42578, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=153.355, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8912, scale=0.4274, index="5200/index-5201-05.fits"
# INFO:root:solve 76: logodds=153.359, matches=26, conflicts=0, distractors=5, ra=114.538, dec=38.8913, scale=0.427186, index="5200/index-5201-05.fits"
# INFO:root:solve 76: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 76: logodds=173.592, matches=21, conflicts=0, distractors=9, ra=114.538, dec=38.891, scale=0.427389, index="5200/index-5203-05.fits"
# INFO:root:solve 76: logodds=173.322, matches=21, conflicts=0, distractors=9, ra=114.538, dec=38.891, scale=0.426632, index="5200/index-5203-05.fits"
# INFO:root:solve 76: logodds=165.043, matches=20, conflicts=0, distractors=10, ra=114.538, dec=38.891, scale=0.427047, index="5200/index-5203-05.fits"
# INFO:root:solve 77: start
# INFO:root:solve 77: slice=[0, 25) (1 / 4), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 77: logodds=291.789, matches=59, conflicts=1, distractors=36, ra=114.542, dec=38.8865, scale=0.426264, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=290.717, matches=59, conflicts=1, distractors=37, ra=114.541, dec=38.8866, scale=0.42627, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=295.337, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8871, scale=0.427269, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=299.815, matches=59, conflicts=1, distractors=36, ra=114.541, dec=38.8866, scale=0.426798, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=290.185, matches=59, conflicts=1, distractors=36, ra=114.541, dec=38.8866, scale=0.425627, index="5200/index-5201-05.fits"
# INFO:root:solve 77: slice=[0, 25) (1 / 4), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 77: slice=[25, 50) (2 / 4), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 77: logodds=305.76, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8869, scale=0.427222, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=316.053, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8868, scale=0.427212, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=299.947, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8867, scale=0.4269, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=307.452, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8869, scale=0.42714, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=306.648, matches=59, conflicts=3, distractors=37, ra=114.541, dec=38.8869, scale=0.42714, index="5200/index-5201-05.fits"
# INFO:root:solve 77: slice=[25, 50) (2 / 4), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 77: logodds=160.695, matches=24, conflicts=0, distractors=67, ra=114.541, dec=38.8872, scale=0.427256, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.729, matches=24, conflicts=0, distractors=67, ra=114.541, dec=38.8872, scale=0.427255, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.721, matches=24, conflicts=0, distractors=67, ra=114.541, dec=38.8871, scale=0.427252, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.755, matches=24, conflicts=0, distractors=67, ra=114.541, dec=38.8871, scale=0.427251, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.72, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8864, scale=0.427278, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.753, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8864, scale=0.427277, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.737, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8864, scale=0.427274, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.771, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8864, scale=0.427273, index="5200/index-5203-05.fits"
# INFO:root:solve 77: slice=[50, 75) (3 / 4), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 77: logodds=314.576, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8868, scale=0.42721, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=320.043, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8866, scale=0.427264, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=306.641, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8866, scale=0.427129, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=316.38, matches=59, conflicts=2, distractors=36, ra=114.541, dec=38.8866, scale=0.426277, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=320.783, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8867, scale=0.427043, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=320.505, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8867, scale=0.42715, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.009, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.427049, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.836, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.427094, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.373, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.427051, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=311.461, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8868, scale=0.427107, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=305.126, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.426862, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=326.396, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427109, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=317.22, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.426938, index="5200/index-5201-05.fits"
# INFO:root:solve 77: slice=[50, 75) (3 / 4), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 77: logodds=160.017, matches=24, conflicts=0, distractors=66, ra=114.541, dec=38.887, scale=0.426898, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.429, matches=24, conflicts=0, distractors=67, ra=114.541, dec=38.8869, scale=0.427153, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.041, matches=24, conflicts=0, distractors=66, ra=114.541, dec=38.8869, scale=0.426894, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.044, matches=24, conflicts=0, distractors=66, ra=114.542, dec=38.8865, scale=0.42692, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.412, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8865, scale=0.427176, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.448, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8865, scale=0.427175, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.061, matches=24, conflicts=0, distractors=66, ra=114.542, dec=38.8865, scale=0.426916, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.427, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8865, scale=0.427172, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=160.463, matches=24, conflicts=0, distractors=67, ra=114.542, dec=38.8865, scale=0.427171, index="5200/index-5203-05.fits"
# INFO:root:solve 77: slice=[75, 100) (4 / 4), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 77: logodds=326.493, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8866, scale=0.427058, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=307.524, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.426566, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=313.351, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.426509, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=314.604, matches=59, conflicts=1, distractors=38, ra=114.541, dec=38.8866, scale=0.426765, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=327.338, matches=59, conflicts=2, distractors=37, ra=114.541, dec=38.8867, scale=0.427142, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=324.422, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427118, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=327.641, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427167, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=327.391, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427167, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=321.468, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8865, scale=0.427129, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=316.808, matches=58, conflicts=0, distractors=40, ra=114.541, dec=38.8866, scale=0.426178, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=316.457, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8865, scale=0.426871, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.06, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8863, scale=0.42716, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=297.709, matches=59, conflicts=1, distractors=36, ra=114.541, dec=38.8866, scale=0.426561, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=298.099, matches=59, conflicts=1, distractors=36, ra=114.541, dec=38.8866, scale=0.426671, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=318.78, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427177, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=318.65, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8865, scale=0.42713, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=302.24, matches=59, conflicts=2, distractors=36, ra=114.541, dec=38.8866, scale=0.427106, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=314.197, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8864, scale=0.427173, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=304.037, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8863, scale=0.427197, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=313.521, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8866, scale=0.427002, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.608, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8864, scale=0.427097, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=312.434, matches=59, conflicts=3, distractors=36, ra=114.541, dec=38.8863, scale=0.427213, index="5200/index-5201-05.fits"
# INFO:root:solve 77: logodds=299.146, matches=60, conflicts=1, distractors=37, ra=114.541, dec=38.8867, scale=0.424655, index="5200/index-5201-05.fits"
# INFO:root:solve 77: slice=[75, 100) (4 / 4), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 77: logodds=163.603, matches=24, conflicts=1, distractors=64, ra=114.541, dec=38.8867, scale=0.426535, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.199, matches=24, conflicts=0, distractors=65, ra=114.541, dec=38.8869, scale=0.427322, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.217, matches=24, conflicts=0, distractors=65, ra=114.541, dec=38.8866, scale=0.427339, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.009, matches=24, conflicts=1, distractors=64, ra=114.541, dec=38.8866, scale=0.425033, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=159.338, matches=24, conflicts=1, distractors=64, ra=114.541, dec=38.8866, scale=0.425022, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=164.287, matches=24, conflicts=0, distractors=64, ra=114.541, dec=38.8866, scale=0.425576, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.426, matches=24, conflicts=1, distractors=64, ra=114.541, dec=38.8866, scale=0.426717, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.987, matches=24, conflicts=1, distractors=64, ra=114.541, dec=38.8866, scale=0.426998, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=161.11, matches=23, conflicts=0, distractors=57, ra=114.541, dec=38.8866, scale=0.426496, index="5200/index-5203-05.fits"
# INFO:root:solve 77: logodds=155.517, matches=24, conflicts=1, distractors=65, ra=114.541, dec=38.8866, scale=0.426497, index="5200/index-5203-05.fits"
# INFO:root:solve 78: start
# INFO:root:solve 78: slice=[0, 25) (1 / 3), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 78: logodds=299.455, matches=60, conflicts=1, distractors=32, ra=114.542, dec=38.8871, scale=0.426329, index="5200/index-5201-05.fits"
# ...
# INFO:root:solve 101: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 102: start
# INFO:root:solve 102: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 102: logodds=162.262, matches=30, conflicts=0, distractors=5, ra=114.544, dec=38.8915, scale=0.427855, index="5200/index-5201-05.fits"
# INFO:root:solve 102: logodds=163.801, matches=30, conflicts=0, distractors=5, ra=114.544, dec=38.8913, scale=0.426534, index="5200/index-5201-05.fits"
# INFO:root:solve 102: logodds=161.721, matches=30, conflicts=0, distractors=5, ra=114.544, dec=38.8912, scale=0.428131, index="5200/index-5201-05.fits"
# INFO:root:solve 102: logodds=174.333, matches=30, conflicts=0, distractors=5, ra=114.544, dec=38.8911, scale=0.426041, index="5200/index-5201-05.fits"
# INFO:root:solve 102: logodds=170.432, matches=30, conflicts=0, distractors=5, ra=114.544, dec=38.8911, scale=0.426953, index="5200/index-5201-05.fits"
# INFO:root:solve 102: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 102: logodds=169.126, matches=21, conflicts=0, distractors=13, ra=114.544, dec=38.8918, scale=0.429193, index="5200/index-5203-05.fits"
# INFO:root:solve 103: start
# INFO:root:solve 103: slice=[0, 16) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 103: logodds=43.0514, matches=8, conflicts=0, distractors=2, ra=114.538, dec=38.888, scale=0.424133, index="5200/index-5201-05.fits"
# INFO:root:solve 103: logodds=46.7496, matches=8, conflicts=0, distractors=2, ra=114.538, dec=38.888, scale=0.424175, index="5200/index-5201-05.fits"
# INFO:root:solve 103: logodds=42.3095, matches=8, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426768, index="5200/index-5201-05.fits"
# INFO:root:solve 103: logodds=46.8674, matches=9, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.42478, index="5200/index-5201-05.fits"
# INFO:root:solve 103: slice=[0, 16) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 103: logodds=64.5255, matches=8, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.424013, index="5200/index-5203-05.fits"
# INFO:root:solve 104: start
# INFO:root:solve 104: slice=[0, 17) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 104: logodds=34.8102, matches=7, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.424163, index="5200/index-5201-05.fits"
# INFO:root:solve 104: logodds=38.4898, matches=7, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.424201, index="5200/index-5201-05.fits"
# INFO:root:solve 104: logodds=34.0036, matches=7, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.426764, index="5200/index-5201-05.fits"
# INFO:root:solve 104: logodds=40.1976, matches=8, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424829, index="5200/index-5201-05.fits"
# INFO:root:solve 104: slice=[0, 17) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 104: logodds=64.9928, matches=8, conflicts=0, distractors=3, ra=114.538, dec=38.8882, scale=0.426714, index="5200/index-5203-05.fits"
# INFO:root:solve 104: logodds=65.0106, matches=8, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.42672, index="5200/index-5203-05.fits"
# INFO:root:solve 104: logodds=54.9253, matches=7, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.42402, index="5200/index-5203-05.fits"
# INFO:root:solve 105: start
# INFO:root:solve 105: slice=[0, 15) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 105: slice=[0, 15) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 105: logodds=33.5895, matches=5, conflicts=0, distractors=3, ra=114.538, dec=38.8903, scale=0.424979, index="5200/index-5203-05.fits"
# INFO:root:solve 106: start
# INFO:root:solve 106: slice=[0, 20) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 106: logodds=45.3407, matches=9, conflicts=1, distractors=5, ra=114.538, dec=38.8879, scale=0.424893, index="5200/index-5201-05.fits"
# INFO:root:solve 106: logodds=48.6585, matches=9, conflicts=1, distractors=5, ra=114.538, dec=38.888, scale=0.424244, index="5200/index-5201-05.fits"
# INFO:root:solve 106: logodds=44.4232, matches=9, conflicts=1, distractors=6, ra=114.538, dec=38.888, scale=0.427034, index="5200/index-5201-05.fits"
# INFO:root:solve 106: logodds=49.8457, matches=10, conflicts=0, distractors=5, ra=114.538, dec=38.888, scale=0.424355, index="5200/index-5201-05.fits"
# INFO:root:solve 106: slice=[0, 20) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 106: logodds=79.0898, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.8887, scale=0.426359, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.1286, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.8881, scale=0.426361, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=69.8707, matches=9, conflicts=0, distractors=7, ra=114.538, dec=38.8881, scale=0.425646, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.7816, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.426033, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.1799, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.8881, scale=0.426429, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.7589, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.8885, scale=0.426032, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.1574, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.8884, scale=0.426426, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.8213, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.426025, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.2218, matches=10, conflicts=0, distractors=6, ra=114.538, dec=38.888, scale=0.426421, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=79.495, matches=10, conflicts=1, distractors=5, ra=114.538, dec=38.888, scale=0.426861, index="5200/index-5203-05.fits"
# INFO:root:solve 106: logodds=70.0445, matches=9, conflicts=1, distractors=6, ra=114.538, dec=38.888, scale=0.423277, index="5200/index-5203-05.fits"
# INFO:root:solve 107: start
# INFO:root:solve 107: slice=[0, 18) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 107: logodds=45.1388, matches=9, conflicts=0, distractors=4, ra=114.534, dec=38.8879, scale=0.425406, index="5200/index-5201-05.fits"
# INFO:root:solve 107: logodds=49.4753, matches=9, conflicts=0, distractors=4, ra=114.534, dec=38.888, scale=0.424895, index="5200/index-5201-05.fits"
# INFO:root:solve 107: logodds=39.5823, matches=8, conflicts=0, distractors=6, ra=114.533, dec=38.888, scale=0.426775, index="5200/index-5201-05.fits"
# INFO:root:solve 107: logodds=44.2617, matches=9, conflicts=0, distractors=5, ra=114.534, dec=38.888, scale=0.424724, index="5200/index-5201-05.fits"
# INFO:root:solve 107: slice=[0, 18) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 107: logodds=61.5979, matches=8, conflicts=0, distractors=6, ra=114.534, dec=38.888, scale=0.423956, index="5200/index-5203-05.fits"
# INFO:root:solve 108: start
# INFO:root:solve 108: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 108: logodds=71.932, matches=13, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424293, index="5200/index-5201-05.fits"
# INFO:root:solve 108: logodds=64.8507, matches=13, conflicts=0, distractors=9, ra=114.538, dec=38.8883, scale=0.427944, index="5200/index-5201-05.fits"
# INFO:root:solve 108: logodds=76.4414, matches=13, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424052, index="5200/index-5201-05.fits"
# INFO:root:solve 108: logodds=66.6869, matches=13, conflicts=0, distractors=9, ra=114.538, dec=38.8881, scale=0.426896, index="5200/index-5201-05.fits"
# INFO:root:solve 108: logodds=69.1756, matches=13, conflicts=0, distractors=8, ra=114.538, dec=38.888, scale=0.426494, index="5200/index-5201-05.fits"
# INFO:root:solve 108: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 108: logodds=116.285, matches=14, conflicts=0, distractors=4, ra=114.539, dec=38.8888, scale=0.426628, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=116.345, matches=14, conflicts=0, distractors=4, ra=114.538, dec=38.8884, scale=0.426602, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=116.682, matches=14, conflicts=0, distractors=4, ra=114.538, dec=38.8886, scale=0.425657, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=116.729, matches=14, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.425639, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=115.493, matches=14, conflicts=0, distractors=6, ra=114.538, dec=38.8882, scale=0.426241, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=109.982, matches=13, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.424971, index="5200/index-5203-05.fits"
# INFO:root:solve 108: logodds=116.48, matches=14, conflicts=0, distractors=3, ra=114.538, dec=38.8882, scale=0.426737, index="5200/index-5203-05.fits"
# INFO:root:solve 109: start
# INFO:root:solve 109: slice=[0, 25) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 109: logodds=72.8511, matches=13, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.424349, index="5200/index-5201-05.fits"
# INFO:root:solve 109: logodds=66.9917, matches=13, conflicts=0, distractors=7, ra=114.538, dec=38.8883, scale=0.428006, index="5200/index-5201-05.fits"
# INFO:root:solve 109: logodds=77.4715, matches=13, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.42402, index="5200/index-5201-05.fits"
# INFO:root:solve 109: logodds=68.7731, matches=13, conflicts=0, distractors=7, ra=114.538, dec=38.8881, scale=0.426928, index="5200/index-5201-05.fits"
# INFO:root:solve 109: logodds=74.3361, matches=14, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425622, index="5200/index-5201-05.fits"
# INFO:root:solve 109: slice=[0, 25) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 109: logodds=115.632, matches=14, conflicts=0, distractors=4, ra=114.539, dec=38.8888, scale=0.426695, index="5200/index-5203-05.fits"
# INFO:root:solve 109: logodds=116.418, matches=14, conflicts=0, distractors=3, ra=114.538, dec=38.8886, scale=0.425674, index="5200/index-5203-05.fits"
# INFO:root:solve 109: logodds=109.334, matches=13, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.424956, index="5200/index-5203-05.fits"
# INFO:root:solve 109: logodds=106.851, matches=13, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.4239, index="5200/index-5203-05.fits"
# INFO:root:solve 109: logodds=107.653, matches=13, conflicts=0, distractors=2, ra=114.538, dec=38.888, scale=0.423834, index="5200/index-5203-05.fits"
# INFO:root:solve 109: logodds=110.079, matches=13, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.424123, index="5200/index-5203-05.fits"
# INFO:root:solve 110: start
# INFO:root:solve 110: slice=[0, 24) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 110: logodds=52.9681, matches=10, conflicts=0, distractors=4, ra=114.538, dec=38.8901, scale=0.424178, index="5200/index-5201-05.fits"
# INFO:root:solve 110: logodds=58.7002, matches=10, conflicts=0, distractors=3, ra=114.538, dec=38.8901, scale=0.424374, index="5200/index-5201-05.fits"
# INFO:root:solve 110: logodds=48.5324, matches=10, conflicts=0, distractors=9, ra=114.538, dec=38.8902, scale=0.426622, index="5200/index-5201-05.fits"
# INFO:root:solve 110: logodds=54.2001, matches=11, conflicts=0, distractors=7, ra=114.538, dec=38.8901, scale=0.425545, index="5200/index-5201-05.fits"
# INFO:root:solve 110: slice=[0, 24) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 110: logodds=87.1515, matches=11, conflicts=0, distractors=6, ra=114.539, dec=38.8909, scale=0.426147, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=87.243, matches=11, conflicts=0, distractors=6, ra=114.538, dec=38.8903, scale=0.426137, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=88.8392, matches=11, conflicts=0, distractors=5, ra=114.538, dec=38.8907, scale=0.425597, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=86.6608, matches=11, conflicts=0, distractors=7, ra=114.538, dec=38.8906, scale=0.426146, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=88.9124, matches=11, conflicts=0, distractors=5, ra=114.538, dec=38.8902, scale=0.425591, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=86.7355, matches=11, conflicts=0, distractors=7, ra=114.538, dec=38.8902, scale=0.426138, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=87.9676, matches=11, conflicts=0, distractors=5, ra=114.538, dec=38.8902, scale=0.426693, index="5200/index-5203-05.fits"
# INFO:root:solve 110: logodds=80.9974, matches=10, conflicts=0, distractors=5, ra=114.538, dec=38.8901, scale=0.424413, index="5200/index-5203-05.fits"
# INFO:root:solve 111: start
# INFO:root:solve 111: slice=[0, 22) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 111: logodds=53.1943, matches=10, conflicts=0, distractors=4, ra=114.538, dec=38.8881, scale=0.424665, index="5200/index-5201-05.fits"
# INFO:root:solve 111: logodds=57.5535, matches=10, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424264, index="5200/index-5201-05.fits"
# INFO:root:solve 111: logodds=50.8299, matches=10, conflicts=0, distractors=7, ra=114.538, dec=38.888, scale=0.426395, index="5200/index-5201-05.fits"
# INFO:root:solve 111: logodds=56.5241, matches=11, conflicts=0, distractors=5, ra=114.538, dec=38.888, scale=0.426279, index="5200/index-5201-05.fits"
# INFO:root:solve 111: slice=[0, 22) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 111: logodds=86.7003, matches=11, conflicts=0, distractors=7, ra=114.538, dec=38.8884, scale=0.427385, index="5200/index-5203-05.fits"
# INFO:root:solve 111: logodds=88.5369, matches=11, conflicts=0, distractors=5, ra=114.538, dec=38.8882, scale=0.426005, index="5200/index-5203-05.fits"
# INFO:root:solve 111: logodds=86.4896, matches=11, conflicts=0, distractors=7, ra=114.538, dec=38.8882, scale=0.426623, index="5200/index-5203-05.fits"
# INFO:root:solve 111: logodds=87.4909, matches=11, conflicts=0, distractors=6, ra=114.538, dec=38.8882, scale=0.42698, index="5200/index-5203-05.fits"
# INFO:root:solve 111: logodds=80.9246, matches=10, conflicts=0, distractors=5, ra=114.538, dec=38.888, scale=0.424221, index="5200/index-5203-05.fits"
# INFO:root:solve 112: start
# INFO:root:solve 112: slice=[0, 19) (1 / 1), index="5200/index-5201-05.fits" (1 / 2)
# INFO:root:solve 112: logodds=59.796, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.8883, scale=0.425234, index="5200/index-5201-05.fits"
# INFO:root:solve 112: logodds=63.7717, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.424005, index="5200/index-5201-05.fits"
# INFO:root:solve 112: logodds=59.7342, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.426321, index="5200/index-5201-05.fits"
# INFO:root:solve 112: logodds=63.8807, matches=12, conflicts=0, distractors=3, ra=114.538, dec=38.888, scale=0.426272, index="5200/index-5201-05.fits"
# INFO:root:solve 112: slice=[0, 19) (1 / 1), index="5200/index-5203-05.fits" (2 / 2)
# INFO:root:solve 112: logodds=90.6482, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.425167, index="5200/index-5203-05.fits"
# INFO:root:solve 112: logodds=90.2042, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.423658, index="5200/index-5203-05.fits"
# INFO:root:solve 112: logodds=90.4072, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.423688, index="5200/index-5203-05.fits"
# INFO:root:solve 112: logodds=91.5079, matches=11, conflicts=0, distractors=4, ra=114.538, dec=38.888, scale=0.423926, index="5200/index-5203-05.fits"

# %%
HR = Stack(groups['Harris-R'])
HB = Stack(groups['Harris-B'])
HV = Stack(groups['Harris-V'])
BU = Stack(groups['Bessell-U'])

stacks = {
    'Harris-R': HR,
    'Harris-B': HB,
    'Harris-V': HV,
    'Bessell-U': BU
}

# Compute vmin and vmax from just one image (or any)
Rvmin, Rvmax = np.percentile(HR, (2, 98))  # or (1, 99)
Rnorm = ImageNormalize(vmin=Rvmin, vmax=Rvmax)
Bvmin, Bvmax = np.percentile(HB, (2, 98))  # or (1, 99)
Bnorm = ImageNormalize(vmin=Bvmin, vmax=Bvmax)
Vvmin, Vvmax = np.percentile(HV, (2, 98))  # or (1, 99)
Vnorm = ImageNormalize(vmin=Vvmin, vmax=Vvmax)
Uvmin, Uvmax = np.percentile(BU, (2, 98))  # or (1, 99)
Unorm = ImageNormalize(vmin=Uvmin, vmax=Uvmax)

fig, axes = plt.subplots(2, 2, figsize=(10, 10))

axes[0, 0].imshow(HR, cmap='gray', norm=Rnorm, origin='lower')
axes[0, 0].set_title("Harris-R")
axes[0, 0].axis('off')

axes[0, 1].imshow(HB, cmap='gray', norm=Bnorm, origin='lower')
axes[0, 1].set_title("Harris-B")
axes[0, 1].axis('off')

axes[1, 0].imshow(HV, cmap='gray', norm=Vnorm, origin='lower')
axes[1, 0].set_title("Harris-V")
axes[1, 0].axis('off')

axes[1, 1].imshow(BU, cmap='gray', norm=Unorm, origin='lower')
axes[1, 1].set_title("Bessell-U")
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
Rhalf = hlr(HR, x0=650, y0=620)
print(f"Half-light radius: {r_half:.1f} pixels")
Bhalf = hlr(HB, x0=650, y0=620)
print(f"Half-light radius: {r_half:.1f} pixels")
Vhalf = hlr(HV, x0=650, y0=620)
print(f"Half-light radius: {r_half:.1f} pixels")
Uhalf = hlr(BU, x0=650, y0=620)
print(f"Half-light radius: {r_half:.1f} pixels")
# Out:
# Half-light radius: 463.0 pixels
# Half-light radius: 463.0 pixels
# Half-light radius: 463.0 pixels
# Half-light radius: 463.0 pixels

# %%
mass()
mass()
mass()
mass()

# %%
import pandas as pd
img_aligned = Stack(groups['Harris-R'])
phot_table, radii = Starfinding({'stacked': {'flatdata': img_aligned}})
r_table = phot_table['stacked']

last = len(r_table.columns)

column = []

for j in range(0,len(r_table)):
    column.append([])
    for i in range(3,last):
        column[-1].append(r_table[j][i]/r_table[j][last-1])

df = pd.DataFrame(column)        
df = df[(df[0]>0.3) & (df[0]<1) & (df[1]>0.3) & (df[1] < 1)]

ap_frac = []
for i in range(3,last):
    ap_frac = np.append(ap_frac,df[i-3].mean())
print("radii:", radii)
print("ap_frac:", ap_frac)
print("lengths:", len(radii), len(ap_frac))
print("DataFrame shape:", df.shape)
plt.plot(radii,ap_frac)  
plt.xlabel('Radius (pix)')
plt.ylabel('Flux Fraction')
# Out:
# radii: [3.0, 4.0, 5.0, 7.0, 10.0, 15.0, 25.0, 40.0]
# ap_frac: [nan nan nan nan nan nan nan nan]
# lengths: 8 8
# DataFrame shape: (0, 8)
# Text(0, 0.5, 'Flux Fraction')
